# %%
# !head -10 medical_stock_prices.csv
# Out:
# 5/4/12,18.38,10.07,23.84864367,3.2,7.670609364,37.5,37.41068834,6.765010
# 12/30/14,36.86,25.41,54.92,4.08,16.8411289,73.57,60.00405471,14.58300801

# %%
import csv
import pandas
import numpy as np
import matplotlib.pyplot as plt
import random
import neuralnetworks as nn

# %%
def csv_read(filename):
	with open(filename, 'r') as f:
		reader = csv.reader(f)
		matrix = list(reader)
	return matrix
